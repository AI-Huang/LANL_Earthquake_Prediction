# %% [markdown]
# # Data Preview
#
# 原数据维度：629145480, 2
#
# 现在取一部分

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
# @Date    : Feb-08-22 23:06
# @Author  : Kelley Kan HUANG (kan.huang@connect.ust.hk)

import os
import numpy as np
from datasets_utils import load_data

# %%
BASE_PATH = "E:\DeepLearningData\LANL-Earthquake-Prediction\processed"
train_acoustic_data = load_data(path=BASE_PATH, name="train_acoustic_data")
train_time_to_failure = load_data(path=BASE_PATH, name="train_time_to_failure")
# Out:
# load time used: 0.00024939999999773477 seconds.
# load time used: 0.0009833000000014636 seconds.

# %%
# View data's shape
print(train_acoustic_data.shape)
print(train_time_to_failure.shape)
# Out:
# (629145480,)
# (629145480,)
